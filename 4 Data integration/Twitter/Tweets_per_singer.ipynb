# %% [markdown]
# # DATAFRAME DIVISI PER CANTANTI NOMINATI NEI TWEET

# %%
import pandas as pd

# %%
df_compound = pd.read_csv("sanremocompound.csv")

# %%
df_compound.rename(columns={'testo':'tweet'},inplace=True)
df_compound

# %%
df=df_compound

# %% [markdown]
# ### Renga

# %%
df_renga=df[df['tweet'].str.contains('renga')==True]

# %%
df_renga

# %%
df_renga_2=df[df['tweet'].str.contains('francesco')==True]

# %%
df_renga_tot= df_renga.append(df_renga_2, ignore_index=True)

# %%
df_renga_tot

# %%
df_renga_tot["conc"] = df_renga_tot['username'] + df_renga_tot['tweet']

# %%
df_renga_tot[(df_renga_tot['conc'].duplicated() == True)]

# %%
df_renga_tot_no_duplicates = df_renga_tot.drop_duplicates(subset=['conc'], keep="last")

# %%
df_renga_tot_no_duplicates

# %%
new_df_renga=df_renga_tot_no_duplicates.assign(cantanti='renga')

# %%
new_df_renga

# %% [markdown]
# ## Fedez e Michielin

# %%
df_fedez=df[df['tweet'].str.contains('fedez')==True]
df_fedez_2=df[df['tweet'].str.contains('michielin')==True]
df_fedez_tot= df_fedez.append(df_fedez_2, ignore_index=True)
df_fedez_tot["conc"] = df_fedez_tot['username'] + df_fedez_tot['tweet']
df_fedez_tot[(df_fedez_tot['conc'].duplicated() == True)]
df_fedez_tot_no_duplicates = df_fedez_tot.drop_duplicates(subset=['conc'], keep="last")
new_df_fedez=df_fedez_tot_no_duplicates.assign(cantanti='fedez e michielin')

# %%
new_df_fedez

# %% [markdown]
# ## Coma_Cose

# %%
df_coma_cose=df[df['tweet'].str.contains('coma_cose')==True]
df_coma_cose_2=df[df['tweet'].str.contains('coma cose')==True]
df_coma_cose_tot= df_coma_cose.append(df_coma_cose_2, ignore_index=True)
df_coma_cose_tot["conc"] = df_coma_cose_tot['username'] + df_coma_cose_tot['tweet']
df_coma_cose_tot[(df_coma_cose_tot['conc'].duplicated() == True)]
df_coma_cose_tot_no_duplicates = df_coma_cose_tot.drop_duplicates(subset=['conc'], keep="last")
new_df_coma_cose=df_coma_cose_tot_no_duplicates.assign(cantanti='coma_cose')

# %%
new_df_coma_cose

# %% [markdown]
# ## Gaia

# %%
df_gaia=df[df['tweet'].str.contains('gaia')==True]

# %%
df_gaia["conc"] = df_gaia['username'] + df_gaia['tweet']

# %%
df_gaia

# %%
new_df_gaia=df_gaia.assign(cantanti='gaia')

# %%
new_df_gaia

# %% [markdown]
# ## Irama

# %%
df_irama=df[df['tweet'].str.contains('irama')==True]
df_irama["conc"] = df_irama['username'] + df_irama['tweet']
new_df_irama=df_irama.assign(cantanti='irama')

# %%
new_df_irama

# %% [markdown]
# ## Fulminacci

# %%
df_fulminacci=df[df['tweet'].str.contains('fulminacci')==True]
df_fulminacci["conc"] = df_fulminacci['username'] + df_fulminacci['tweet']
new_df_fulminacci=df_fulminacci.assign(cantanti='fulminacci')
new_df_fulminacci

# %% [markdown]
# ## Madame

# %%
df_madame=df[df['tweet'].str.contains('madame')==True]
df_madame["conc"] = df_madame['username'] + df_madame['tweet']
new_df_madame=df_madame.assign(cantanti='madame')
new_df_madame

# %% [markdown]
# ## Willie Peyote

# %%
df_willie=df[df['tweet'].str.contains('willie')==True]
df_willie_2=df[df['tweet'].str.contains('peyote')==True]
df_willie_tot= df_willie.append(df_willie_2, ignore_index=True)
df_willie_tot["conc"] = df_willie_tot['username'] + df_willie_tot['tweet']
df_willie_tot[(df_willie_tot['conc'].duplicated() == True)]
df_willie_tot_no_duplicates = df_willie_tot.drop_duplicates(subset=['conc'], keep="last")
new_df_willie=df_willie_tot_no_duplicates.assign(cantanti='willie peyote')
new_df_willie

# %% [markdown]
# ## Orietta Berti

# %%
df_orietta=df[df['tweet'].str.contains('orietta')==True]
df_orietta_2=df[df['tweet'].str.contains('berti')==True]
df_orietta_tot= df_orietta.append(df_orietta_2, ignore_index=True)
df_orietta_tot["conc"] = df_orietta_tot['username'] + df_orietta_tot['tweet']
df_orietta_tot[(df_orietta_tot['conc'].duplicated() == True)]
df_orietta_tot_no_duplicates = df_orietta_tot.drop_duplicates(subset=['conc'], keep="last")
new_df_orietta=df_orietta_tot_no_duplicates.assign(cantanti='orietta berti')
new_df_orietta

# %% [markdown]
# ## Ermal Meta

# %%
df_ermal=df[df['tweet'].str.contains('ermal')==True]
df_ermal_2=df[df['tweet'].str.contains('meta')==True]
df_ermal_tot= df_ermal.append(df_ermal_2, ignore_index=True)
df_ermal_tot["conc"] = df_ermal_tot['username'] + df_ermal_tot['tweet']
df_ermal_tot[(df_ermal_tot['conc'].duplicated() == True)]
df_ermal_tot_no_duplicates = df_ermal_tot.drop_duplicates(subset=['conc'], keep="last")
new_df_ermal=df_ermal_tot_no_duplicates.assign(cantanti='ermal meta')
new_df_ermal

# %% [markdown]
# ## Fasma

# %%
df_fasma=df[df['tweet'].str.contains('fasma')==True]
df_fasma["conc"] = df_fasma['username'] + df_fasma['tweet']
new_df_fasma=df_fasma.assign(cantanti='fasma')
new_df_fasma

# %% [markdown]
# ## Arisa

# %%
df_arisa=df[df['tweet'].str.contains('arisa')==True]
df_arisa["conc"] = df_arisa['username'] + df_arisa['tweet']
new_df_arisa=df_arisa.assign(cantanti='arisa')
new_df_arisa

# %% [markdown]
# ## Giò Evan

# %%
df_evan=df[df['tweet'].str.contains('giò')==True]
df_evan_2=df[df['tweet'].str.contains('gio evan')==True]
df_evan_tot= df_evan.append(df_evan_2, ignore_index=True)
df_evan_tot["conc"] = df_evan_tot['username'] + df_evan_tot['tweet']
df_evan_tot[(df_evan_tot['conc'].duplicated() == True)]
df_evan_tot_no_duplicates = df_evan_tot.drop_duplicates(subset=['conc'], keep="last")
new_df_evan=df_evan_tot_no_duplicates.assign(cantanti='giò evan')
new_df_evan

# %% [markdown]
# ## Maneskin

# %%
df_maneskin=df[df['tweet'].str.contains('maneskin')==True]
df_maneskin["conc"] = df_maneskin['username'] + df_maneskin['tweet']
new_df_maneskin=df_maneskin.assign(cantanti='maneskin')
new_df_maneskin

# %% [markdown]
# ## Malika Ayane

# %%
df_malika=df[df['tweet'].str.contains('malika')==True]
df_malika_2=df[df['tweet'].str.contains('ayane')==True]
df_malika_tot= df_malika.append(df_malika_2, ignore_index=True)
df_malika_tot["conc"] = df_malika_tot['username'] + df_malika_tot['tweet']
df_malika_tot[(df_malika_tot['conc'].duplicated() == True)]
df_malika_tot_no_duplicates = df_malika_tot.drop_duplicates(subset=['conc'], keep="last")
new_df_malika=df_malika_tot_no_duplicates.assign(cantanti='malika')
new_df_malika

# %% [markdown]
# ## Aiello

# %%
df_aiello=df[df['tweet'].str.contains('aiello')==True]
df_aiello["conc"] = df_aiello['username'] + df_aiello['tweet']
new_df_aiello=df_aiello.assign(cantanti='aiello')
new_df_aiello

# %% [markdown]
# ## Max Gazzè e Trifluoperazina

# %%
df_gazze=df[df['tweet'].str.contains('gazzè')==True]
df_gazze_2=df[df['tweet'].str.contains('gazzé')==True]
df_gazze_3=df[df['tweet'].str.contains('trifluoperazina')==True]
df_gazze_tot_1= df_gazze.append(df_gazze_2, ignore_index=True)
df_gazze_tot_2= df_gazze_tot_1.append(df_gazze_3, ignore_index=True)
df_gazze_tot_2["conc"] = df_gazze_tot_2['username'] + df_gazze_tot_2['tweet']
df_gazze_tot_2[(df_gazze_tot_2['conc'].duplicated() == True)]
df_gazze_tot_no_duplicates = df_gazze_tot_2.drop_duplicates(subset=['conc'], keep="last")
new_df_gazze=df_gazze_tot_no_duplicates.assign(cantanti='gazzè e trifluoperazina')
new_df_gazze

# %% [markdown]
# ## Ghemon

# %%
df_ghemon=df[df['tweet'].str.contains('ghemon')==True]
df_ghemon["conc"] = df_ghemon['username'] + df_ghemon['tweet']
new_df_ghemon=df_ghemon.assign(cantanti='ghemon')
new_df_ghemon

# %% [markdown]
# ## La rappresentante di lista

# %%
df_rappresentante=df[df['tweet'].str.contains('rappresentante lista')==True]
df_rappresentante_2=df[df['tweet'].str.contains('lrdl')==True]
df_rappresentante_tot= df_rappresentante.append(df_rappresentante_2, ignore_index=True)
df_rappresentante_tot["conc"] = df_rappresentante_tot['username'] + df_rappresentante_tot['tweet']
df_rappresentante_tot[(df_rappresentante_tot['conc'].duplicated() == True)]
df_rappresentante_tot_no_duplicates = df_rappresentante_tot.drop_duplicates(subset=['conc'], keep="last")
new_df_rappresentante=df_rappresentante_tot_no_duplicates.assign(cantanti='rappresentante lista')
new_df_rappresentante

# %% [markdown]
# ## Noemi

# %%
df_noemi=df[df['tweet'].str.contains('noemi')==True]
df_noemi["conc"] = df_noemi['username'] + df_noemi['tweet']
new_df_noemi=df_noemi.assign(cantanti='noemi')
new_df_noemi

# %% [markdown]
# ## Random

# %%
df_random=df[df['tweet'].str.contains('random')==True]
df_random["conc"] = df_random['username'] + df_random['tweet']
new_df_random=df_random.assign(cantanti='random')
new_df_random

# %% [markdown]
# ## Colapesce e Dimartino

# %%
df_colapesce=df[df['tweet'].str.contains('colapesce')==True]
df_colapesce_2=df[df['tweet'].str.contains('dimartino')==True]
df_colapesce_tot= df_colapesce.append(df_colapesce_2, ignore_index=True)
df_colapesce_tot["conc"] = df_colapesce_tot['username'] + df_colapesce_tot['tweet']
df_colapesce_tot[(df_colapesce_tot['conc'].duplicated() == True)]
df_colapesce_tot_no_duplicates = df_colapesce_tot.drop_duplicates(subset=['conc'], keep="last")
new_df_colapesce=df_colapesce_tot_no_duplicates.assign(cantanti='colapesce dimartino')
new_df_colapesce

# %% [markdown]
# ## Annalisa

# %%
df_annalisa=df[df['tweet'].str.contains('annalisa')==True]
df_annalisa["conc"] = df_annalisa['username'] + df_annalisa['tweet']
new_df_annalisa=df_annalisa.assign(cantanti='annalisa')
new_df_annalisa

# %% [markdown]
# ## Bugo

# %%
df_bugo=df[df['tweet'].str.contains('bugo')==True]
df_bugo["conc"] = df_bugo['username'] + df_bugo['tweet']
new_df_bugo=df_bugo.assign(cantanti='bugo')
new_df_bugo

# %% [markdown]
# ## Lo Stato Sociale

# %%
df_stato_sociale=df[df['tweet'].str.contains('stato sociale')==True]
df_stato_sociale["conc"] = df_stato_sociale['username'] + df_stato_sociale['tweet']
new_df_stato_sociale=df_stato_sociale.assign(cantanti='stato sociale')
new_df_stato_sociale

# %% [markdown]
# ## Extraliscio feat Davide Toffolo

# %%
df_extra=df[df['tweet'].str.contains('extraliscio')==True]
df_extra_2=df[df['tweet'].str.contains('toffolo')==True]
df_extra_tot= df_extra.append(df_extra_2, ignore_index=True)
df_extra_tot["conc"] = df_extra_tot['username'] + df_extra_tot['tweet']
df_extra_tot[(df_extra_tot['conc'].duplicated() == True)]
df_extra_tot_no_duplicates = df_extra_tot.drop_duplicates(subset=['conc'], keep="last")
new_df_extra=df_extra_tot_no_duplicates.assign(cantanti='extraliscio e toffolo')
new_df_extra

# %% [markdown]
# ## unione dataset

# %%
df = pd.concat([new_df_renga,new_df_fedez,new_df_coma_cose,new_df_gaia,new_df_irama,new_df_fulminacci,new_df_madame,new_df_willie,new_df_orietta,new_df_ermal,new_df_fasma,new_df_arisa,new_df_evan,new_df_maneskin,new_df_malika,new_df_aiello,new_df_gazze,new_df_ghemon,new_df_rappresentante,new_df_noemi,new_df_random,new_df_colapesce,new_df_annalisa,new_df_bugo,new_df_stato_sociale,new_df_extra])

# %%
df

# %%
df[(df['conc'].duplicated() == True)]

# %%
df.to_csv('sanremocompound_cantante.csv')

# %%
df_duplicates= df[(df['conc'].duplicated() == True)]

# %%
df_duplicates

# %%
df_duplicates['compound'].mean()

# %%
df_extra= df_duplicates[df_duplicates['cantanti']== "extraliscio e toffolo"]

# %%
df_extra['compound'].mean()

# %%
df_no_duplicates = df.drop_duplicates(subset=['conc'])

# %%
df_no_duplicates

# %%
df_no_duplicates.to_csv('sanremocompound_cantante_pulito.csv')

# %%
df_no_duplicates['interesse'] = np.where((df.like > 2500), df.compound * 1.15, df.compound)

# %%
df_cantanti_e_compound = df_no_duplicates[['data','tweet','username','compound','cantanti','like','followersCount']]

# %%
df_cantanti_e_compound

# %%
df_cantanti_e_compound.to_csv('df_cantanti_e_compound.csv')
